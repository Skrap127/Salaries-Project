# %%
graph = Import["projection_salary(Grouped).graphml"];

# %%
Length[VertexList[graph]]
# Out:
# 101

# %%
projection = GraphPlot[graph]
# Out:
# -Graphics-

# %%
list = TakeSmallestBy[VertexList[graph], VertexDegree[graph, #] &, 12];
Grid[
  Transpose[{list, Table[VertexDegree[graph, list[[i]]], {i, Length[list]}]}], 
  Frame -> All
]
# Out:
# 793512.4 to 800000.0     45
#
# 521033.06 to 527520.66   54
#
# 767561.98 to 774049.59   57
#
# 722148.76 to 728636.36   58
#
# 787024.79 to 793512.4    64
#
# 514545.45 to 521033.06   69
#
# 676735.54 to 683223.14   70
#
# 534008.26 to 540495.87   73
#
# 637809.92 to 644297.52   76
#
# 631322.31 to 637809.92   76
#
# 443181.82 to 449669.42   78
#
# 605371.9 to 611859.5     78

# %%
Histogram[
  VertexDegree[graph],
  9,
  AxesLabel -> {"Grado", "Frecuencia"},
  ChartStyle -> "Pastel"
]
# Out:
# -Graphics-
