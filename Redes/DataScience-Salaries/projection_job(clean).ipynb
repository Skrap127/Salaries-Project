# %%
graph = Import["projection_job(clean).graphml"];

# %%
Length[VertexList[graph]]
# Out:
# 317

# %%
projection = GraphPlot[graph]
# Out:
# -Graphics-

# %%
list = TakeLargestBy[VertexList[graph], VertexDegree[graph, #] &, 12];
Grid[
  Transpose[{list, Table[VertexDegree[graph, list[[i]]], {i, Length[list]}]}], 
  Frame -> All
]
# Out:
# Data Scientist              296
#
# Data Engineer               296
#
# Data Analyst                293
#
# Engineer                    290
#
# Manager                     288
#
# Machine Learning Engineer   288
#
# Software Engineer           287
#
# Analyst                     282
#
# Associate                   278
#
# Research Engineer           275
#
# Developer                   274
#
# Research Scientist          272

# %%
Histogram[
  VertexDegree[graph],
  8,
  AxesLabel -> {"Grado", "Frecuencia"},
  ChartStyle -> "Pastel"
]
# Out:
# -Graphics-
