# %%
graph = Import["projection_job(Grouped5).graphml"];

# %%
Length[VertexList[graph]]

(*Aplicar transformación logarítmica.*)
# Out:
# 317

# %%
N[GraphDensity[graph]]
# Out:
# 0.594298

# %%
projection = GraphPlot[graph]
# Out:
# -Graphics-

# %%
list = TakeSmallestBy[VertexList[graph], VertexDegree[graph, #] &, 12];
Grid[
  Transpose[{list, Table[VertexDegree[graph, list[[i]]], {i, Length[list]}]}], 
  Frame -> All
]
# Out:
# Data Science Tech Lead             8
#
# Analytics Engineering Manager      12
#
# Analytics Analyst                  14
#
# AI Software Development Engineer   17
#
# AWS Data Architect                 23
#
# Principal Data Architect           26
#
# Platform Data Engineer             40
#
# People Data Analyst                40
#
# CRM Data Analyst                   40
#
# Quantitative Research Analyst      45
#
# Applied AI ML Lead                 51
#
# Marketing Data Engineer            51

# %%
BarChart[VertexDegree[graph]]
# Out:
# -Graphics-
